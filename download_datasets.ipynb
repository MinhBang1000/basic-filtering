# %% [markdown]
# # **1. Download Benign Dataset**

# %%
# Check env
import sys, os, platform
print("Python:", sys.version)
print("Platform:", platform.platform())
print("CWD:", os.getcwd())
# Out:
# Python: 3.11.14 (main, Oct 10 2025, 08:54:03) [GCC 11.4.0]
# Platform: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.35
# CWD: /home/bang/projects

# %%
import os

BASE_DIR = "./datasets"
RAW_DIR = os.path.join(BASE_DIR, "raw")
PROC_DIR = os.path.join(BASE_DIR, "processed")
LOG_DIR = os.path.join(RAW_DIR, "logs")   # logs nằm trong raw/logs

print("BASE_DIR:", BASE_DIR)
print("RAW_DIR :", RAW_DIR)
print("PROC_DIR:", PROC_DIR)
print("LOG_DIR :", LOG_DIR)
# Out:
# BASE_DIR: ./datasets
# RAW_DIR : ./datasets/raw
# PROC_DIR: ./datasets/processed
# LOG_DIR : ./datasets/raw/logs

# %%
import os

folders = [
    os.path.join(RAW_DIR, "ultrachat"),
    os.path.join(RAW_DIR, "alpaca"),
    os.path.join(RAW_DIR, "dolly"),
    os.path.join(RAW_DIR, "natural_instructions"),
    LOG_DIR,
    PROC_DIR,
]

for p in folders:
    os.makedirs(p, exist_ok=True)

print("Created folders:")
for p in folders:
    print(" -", p)
# Out:
# Created folders:
#  - ./datasets/raw/ultrachat
#  - ./datasets/raw/alpaca
#  - ./datasets/raw/dolly
#  - ./datasets/raw/natural_instructions
#  - ./datasets/raw/logs
#  - ./datasets/processed

# %% [markdown]
# # **2. Download Mixed Dataset**
